# %%
#Q14 Train an AdaBoost Classifier on a sample dataset and print model accuracy.
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Generate sample data
X, y = make_classification(
    n_samples=500, 
    n_features=4, 
    n_informative=2,
    n_redundant=0, 
    random_state=42
)

# Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Define weak learner (decision stump)
weak_learner = DecisionTreeClassifier(max_depth=1)

# Create AdaBoost Classifier with 50 weak learners
adaboost_model = AdaBoostClassifier(
    estimator=weak_learner,  # Corrected parameter name
    n_estimators=50,
    learning_rate=1.0,
    random_state=42
)

# Train the model
adaboost_model.fit(X_train, y_train)

# Make predictions
y_pred = adaboost_model.predict(X_test)

# Evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of AdaBoost Classifier: {accuracy:.2f}")


#Q15 Train an AdaBoost Regressor and evaluate performance using Mean Absolute Error (MAE).
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# Generate sample data
X, y = make_regression(
    n_samples=500, n_features=4, noise=0.2, random_state=42
)

# Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Define weak learner (decision stump)
weak_learner = DecisionTreeRegressor(max_depth=3)

# Create AdaBoost Regressor with 50 weak learners
adaboost_model = AdaBoostRegressor(
    estimator=weak_learner,
    n_estimators=50,
    learning_rate=1.0,
    random_state=42
)

# Train the model
adaboost_model.fit(X_train, y_train)

# Make predictions
y_pred = adaboost_model.predict(X_test)

# Evaluate using Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error (MAE) of AdaBoost Regressor: {mae:.2f}")

#Q16 Train a Gradient Boosting Classifier on the Breast Cancer dataset and print feature importance.
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
import pandas as pd

# Load the Breast Cancer dataset
data = load_breast_cancer()
X, y = data.data, data.target
feature_names = data.feature_names

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Initialize and train Gradient Boosting Classifier
gb_model = GradientBoostingClassifier(
    n_estimators=100,  # Number of boosting stages
    learning_rate=0.1,
    max_depth=3,
    random_state=42
)

# Fit the model to the training data
gb_model.fit(X_train, y_train)

# Get feature importance
feature_importance = gb_model.feature_importances_

# Create a DataFrame to display feature importance
feature_df = pd.DataFrame(
    {"Feature": feature_names, "Importance": feature_importance}
).sort_values(by="Importance", ascending=False)

# Print feature importance
print("Feature Importance from Gradient Boosting Classifier:\n")
print(feature_df)

#Q17 Train a Gradient Boosting Regressor and evaluate using R-Squared Score.
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# Generate synthetic regression dataset
X, y = make_regression(
    n_samples=500, 
    n_features=4, 
    noise=0.2, 
    random_state=42
)

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Initialize and train Gradient Boosting Regressor
gb_model = GradientBoostingRegressor(
    n_estimators=100,  # Number of boosting stages
    learning_rate=0.1,
    max_depth=3,
    random_state=42
)

# Fit the model to the training data
gb_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = gb_model.predict(X_test)

# Evaluate model performance using R-Squared Score (R²)
r2 = r2_score(y_test, y_pred)
print(f"R-Squared Score (R²) of Gradient Boosting Regressor: {r2:.2f}")

#Q18 Train an XGBoost Classifier on a dataset and compare accuracy with Gradient Boosting.
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Generate a synthetic classification dataset
X, y = make_classification(
    n_samples=500, 
    n_features=4, 
    n_informative=2, 
    n_redundant=0, 
    random_state=42
)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ------------------------------------------
# Train Gradient Boosting Classifier
gb_model = GradientBoostingClassifier(
    n_estimators=100, 
    learning_rate=0.1, 
    max_depth=3, 
    random_state=42
)
gb_model.fit(X_train, y_train)
gb_pred = gb_model.predict(X_test)

# Evaluate Gradient Boosting accuracy
gb_accuracy = accuracy_score(y_test, gb_pred)
print(f"Accuracy of Gradient Boosting Classifier: {gb_accuracy:.2f}")

# ------------------------------------------
# Train XGBoost Classifier
xgb_model = XGBClassifier(
    n_estimators=100, 
    learning_rate=0.1, 
    max_depth=3, 
    random_state=42,
    eval_metric='logloss'  # Correct to suppress warnings
)
xgb_model.fit(X_train, y_train)
xgb_pred = xgb_model.predict(X_test)

# Evaluate XGBoost accuracy
xgb_accuracy = accuracy_score(y_test, xgb_pred)
print(f"Accuracy of XGBoost Classifier: {xgb_accuracy:.2f}")

# ------------------------------------------
# Compare Results
if xgb_accuracy > gb_accuracy:
    print("XGBoost outperforms Gradient Boosting!")
elif xgb_accuracy < gb_accuracy:
    print("Gradient Boosting outperforms XGBoost!")
else:
    print("Both models perform equally well.")

#Q19 Train a CatBoost Classifier and evaluate using F1-Score.
from catboost import CatBoostClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# Generate a synthetic classification dataset
X, y = make_classification(
    n_samples=500, 
    n_features=4, 
    n_informative=2, 
    n_redundant=0, 
    random_state=42
)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ------------------------------------------
# Train CatBoost Classifier
cat_model = CatBoostClassifier(
    iterations=100,         # Number of boosting iterations
    learning_rate=0.1,      # Learning rate
    depth=6,                # Depth of the tree
    verbose=0,              # Silent training
    random_seed=42
)

# Fit the CatBoost model
cat_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = cat_model.predict(X_test)

# ------------------------------------------
# Evaluate using F1-Score
f1 = f1_score(y_test, y_pred)
print(f"F1-Score of CatBoost Classifier: {f1:.2f}")

    
#Q20 Train an XGBoost Regressor and evaluate using Mean Squared Error (MSE).
from xgboost import XGBRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Generate a synthetic regression dataset
X, y = make_regression(
    n_samples=500, 
    n_features=4, 
    noise=0.2, 
    random_state=42
)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ------------------------------------------
# Train XGBoost Regressor
xgb_model = XGBRegressor(
    n_estimators=100,       # Number of boosting rounds
    learning_rate=0.1,      # Learning rate
    max_depth=3,            # Depth of each tree
    random_state=42
)

# Fit the model to training data
xgb_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = xgb_model.predict(X_test)

# ------------------------------------------
# Evaluate using Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error (MSE) of XGBoost Regressor: {mse:.2f}")

#Q21 Train an AdaBoost Classifier and visualize feature importance.
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# Generate a synthetic classification dataset
X, y = make_classification(
    n_samples=500, 
    n_features=4, 
    n_informative=2, 
    n_redundant=0, 
    random_state=42
)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ------------------------------------------
# Train AdaBoost Classifier
adaboost_model = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=1),  # Weak learner (decision stump)
    n_estimators=50,         # Number of weak learners
    learning_rate=1.0,
    random_state=42
)

# Fit the model to training data
adaboost_model.fit(X_train, y_train)

# ------------------------------------------
# Get feature importance
feature_importance = adaboost_model.feature_importances_

# ------------------------------------------
# Visualize feature importance
feature_names = [f"Feature {i}" for i in range(X.shape[1])]
plt.figure(figsize=(8, 6))
plt.barh(feature_names, feature_importance, color='skyblue')
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Feature Importance from AdaBoost Classifier")
plt.show()

#Q22 Train a Gradient Boosting Regressor and plot learning curves.
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Generate a synthetic regression dataset
X, y = make_regression(
    n_samples=500, 
    n_features=4, 
    noise=0.2, 
    random_state=42
)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ------------------------------------------
# Train Gradient Boosting Regressor
gb_model = GradientBoostingRegressor(
    n_estimators=100,       # Number of boosting stages
    learning_rate=0.1,      # Learning rate
    max_depth=3,            # Depth of each tree
    random_state=42
)

# Fit the model to training data
gb_model.fit(X_train, y_train)

# ------------------------------------------
# Plot learning curves
train_errors = []
test_errors = []

# Evaluate model performance at each stage
for i, y_pred in enumerate(gb_model.staged_predict(X_train)):
    train_mse = mean_squared_error(y_train, y_pred)
    train_errors.append(train_mse)

for i, y_pred in enumerate(gb_model.staged_predict(X_test)):
    test_mse = mean_squared_error(y_test, y_pred)
    test_errors.append(test_mse)

# ------------------------------------------
# Plot training and test errors
plt.figure(figsize=(8, 6))
plt.plot(np.arange(1, len(train_errors) + 1), np.sqrt(train_errors), "b-", label="Training Error")
plt.plot(np.arange(1, len(test_errors) + 1), np.sqrt(test_errors), "r-", label="Test Error")
plt.xlabel("Number of Boosting Iterations")
plt.ylabel("Root Mean Squared Error (RMSE)")
plt.title("Learning Curves of Gradient Boosting Regressor")
plt.legend()
plt.show()

#Q23 Train an XGBoost Classifier and visualize feature importance.
import numpy as np
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Generate a synthetic classification dataset
X, y = make_classification(
    n_samples=500, 
    n_features=4, 
    n_informative=2, 
    n_redundant=0, 
    random_state=42
)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ------------------------------------------
# Train XGBoost Classifier
xgb_model = XGBClassifier(
    n_estimators=100,       # Number of boosting rounds
    learning_rate=0.1,      # Learning rate
    max_depth=3,            # Depth of each tree
    random_state=42,
    use_label_encoder=False,
    eval_metric='logloss'   # Suppress warning for newer versions
)

# Fit the model to training data
xgb_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = xgb_model.predict(X_test)

# Evaluate model accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of XGBoost Classifier: {accuracy:.2f}")

# ------------------------------------------
# Get feature importance
feature_importance = xgb_model.feature_importances_

# ------------------------------------------
# Visualize feature importance
feature_names = [f"Feature {i}" for i in range(X.shape[1])]
plt.figure(figsize=(8, 6))
plt.barh(feature_names, feature_importance, color='skyblue')
plt.xlabel("Feature Importance Score")
plt.ylabel("Features")
plt.title("Feature Importance from XGBoost Classifier")
plt.show()

#Q24 Train a CatBoost Classifier and plot the confusion matrix.
import numpy as np
import matplotlib.pyplot as plt
from catboost import CatBoostClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Generate a synthetic classification dataset
X, y = make_classification(
    n_samples=500, 
    n_features=4, 
    n_informative=2, 
    n_redundant=0, 
    random_state=42
)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ------------------------------------------
# Train CatBoost Classifier
cat_model = CatBoostClassifier(
    iterations=100,         # Number of boosting iterations
    learning_rate=0.1,      # Learning rate
    depth=6,                # Depth of the tree
    verbose=0,              # Silent training
    random_seed=42
)

# Fit the model to training data
cat_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = cat_model.predict(X_test)

# ------------------------------------------
# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# ------------------------------------------
# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.title("Confusion Matrix - CatBoost Classifier")
plt.show()

#Q25 Train an AdaBoost Classifier with different numbers of estimators and compare accuracy.
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Generate a synthetic classification dataset
X, y = make_classification(
    n_samples=500, 
    n_features=4, 
    n_informative=2, 
    n_redundant=0, 
    random_state=42
)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ------------------------------------------
# List of different numbers of estimators
n_estimators_list = [10, 50, 100, 200, 300]

# To store accuracy results
accuracy_results = []

# ------------------------------------------
# Train AdaBoost Classifier with different estimators
for n_estimators in n_estimators_list:
    adaboost_model = AdaBoostClassifier(
        estimator=DecisionTreeClassifier(max_depth=1),  # Weak learner
        n_estimators=n_estimators,
        learning_rate=1.0,
        random_state=42
    )
    
    # Fit the model
    adaboost_model.fit(X_train, y_train)
    
    # Make predictions
    y_pred = adaboost_model.predict(X_test)
    
    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_results.append(accuracy)
    print(f"Accuracy with {n_estimators} estimators: {accuracy:.2f}")

# ------------------------------------------
# Plot accuracy vs number of estimators
plt.figure(figsize=(8, 6))
plt.plot(n_estimators_list, accuracy_results, marker='o', linestyle='--', color='b')
plt.xlabel("Number of Estimators")
plt.ylabel("Accuracy Score")
plt.title("Accuracy vs Number of Estimators in AdaBoost")
plt.grid(True)
plt.show()

#Q26 Train a Gradient Boosting Classifier and visualize the ROC curve.
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc

# Generate a synthetic classification dataset
X, y = make_classification(
    n_samples=500, 
    n_features=4, 
    n_informative=2, 
    n_redundant=0, 
    random_state=42
)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ------------------------------------------
# Train Gradient Boosting Classifier
gb_model = GradientBoostingClassifier(
    n_estimators=100,       # Number of boosting rounds
    learning_rate=0.1,      # Learning rate
    max_depth=3,            # Depth of each tree
    random_state=42
)

# Fit the model to training data
gb_model.fit(X_train, y_train)

# Predict probabilities for ROC curve
y_prob = gb_model.predict_proba(X_test)[:, 1]

# ------------------------------------------
# Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

# ------------------------------------------
# 📊 Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f"ROC Curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Gradient Boosting Classifier")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

#Q27 Train an XGBoost Regressor and tune the learning rate using GridSearchCV.
import numpy as np
from xgboost import XGBRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error

# Generate a synthetic regression dataset
X, y = make_regression(
    n_samples=500, 
    n_features=4, 
    noise=0.2, 
    random_state=42
)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ------------------------------------------
# Define XGBoost Regressor
xgb_model = XGBRegressor(
    n_estimators=100,        # Number of boosting rounds
    max_depth=3,             # Depth of each tree
    random_state=42
)

# ------------------------------------------
# Define parameter grid for GridSearchCV
param_grid = {
    'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3]
}

# ------------------------------------------
# Perform GridSearchCV to find the best learning rate
grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    cv=5,                    # 5-fold cross-validation
    scoring='neg_mean_squared_error',
    verbose=1,
    n_jobs=-1
)

# Fit GridSearchCV
grid_search.fit(X_train, y_train)

# ------------------------------------------
# Get the best model and learning rate
best_model = grid_search.best_estimator_
best_learning_rate = grid_search.best_params_['learning_rate']
print(f"Best Learning Rate: {best_learning_rate}")

# ------------------------------------------
# Evaluate model performance on test data
y_pred = best_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error (MSE) with best learning rate: {mse:.2f}")

#Q28 Train a CatBoost Classifier on an imbalanced dataset and compare performance with class weighting.
import numpy as np
import matplotlib.pyplot as plt
from catboost import CatBoostClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix, classification_report

# ------------------------------------------
# Generate an imbalanced classification dataset
X, y = make_classification(
    n_samples=1000, 
    n_features=4, 
    n_informative=2, 
    n_redundant=0, 
    weights=[0.9, 0.1],  # 90% class 0, 10% class 1
    random_state=42
)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ------------------------------------------
# Train CatBoost Classifier without class weights
cat_model_no_weights = CatBoostClassifier(
    iterations=100,         # Number of boosting iterations
    learning_rate=0.1,      # Learning rate
    depth=6,                # Depth of the tree
    verbose=0,              # Silent training
    random_seed=42
)

# Fit the model to training data
cat_model_no_weights.fit(X_train, y_train)
y_pred_no_weights = cat_model_no_weights.predict(X_test)

# Evaluate performance without class weights
f1_no_weights = f1_score(y_test, y_pred_no_weights)
print(f"F1-Score without class weights: {f1_no_weights:.2f}")
print("\nClassification Report without Class Weights:\n", classification_report(y_test, y_pred_no_weights))

# ------------------------------------------
# Train CatBoost Classifier with class weights
class_weights = {0: 1, 1: 10}  # Higher weight for minority class

cat_model_weights = CatBoostClassifier(
    iterations=100,
    learning_rate=0.1,
    depth=6,
    verbose=0,
    class_weights=class_weights,  # Apply class weights
    random_seed=42
)

# Fit the model to training data
cat_model_weights.fit(X_train, y_train)
y_pred_weights = cat_model_weights.predict(X_test)

# Evaluate performance with class weights
f1_weights = f1_score(y_test, y_pred_weights)
print(f"\nF1-Score with class weights: {f1_weights:.2f}")
print("\nClassification Report with Class Weights:\n", classification_report(y_test, y_pred_weights))

# ------------------------------------------
# Compare Confusion Matrices
cm_no_weights = confusion_matrix(y_test, y_pred_no_weights)
cm_weights = confusion_matrix(y_test, y_pred_weights)

# Plot Confusion Matrices
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Without class weights
ax[0].imshow(cm_no_weights, interpolation='nearest', cmap='Blues')
ax[0].set_title('Confusion Matrix - No Class Weights')
ax[0].set_xticks(np.arange(2))
ax[0].set_yticks(np.arange(2))
ax[0].set_xlabel('Predicted Label')
ax[0].set_ylabel('True Label')

# With class weights
ax[1].imshow(cm_weights, interpolation='nearest', cmap='Blues')
ax[1].set_title('Confusion Matrix - With Class Weights')
ax[1].set_xticks(np.arange(2))
ax[1].set_yticks(np.arange(2))
ax[1].set_xlabel('Predicted Label')
ax[1].set_ylabel('True Label')

plt.tight_layout()
plt.show()

#Q29 Train an AdaBoost Classifier and analyze the effect of different learning rates.
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# ------------------------------------------
# Generate a synthetic classification dataset
X, y = make_classification(
    n_samples=500, 
    n_features=4, 
    n_informative=2, 
    n_redundant=0, 
    random_state=42
)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ------------------------------------------
# Define a list of learning rates to test
learning_rates = [0.001, 0.01, 0.1, 0.5, 1.0, 1.5]

# To store accuracy results
accuracy_results = []

# ------------------------------------------
# Train AdaBoost Classifier with different learning rates
for lr in learning_rates:
    adaboost_model = AdaBoostClassifier(
        estimator=DecisionTreeClassifier(max_depth=1),  # Weak learner (decision stump)
        n_estimators=50,         # Number of weak learners
        learning_rate=lr,
        random_state=42
    )
    
    # Fit the model
    adaboost_model.fit(X_train, y_train)
    
    # Make predictions
    y_pred = adaboost_model.predict(X_test)
    
    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_results.append(accuracy)
    print(f"Accuracy with learning rate {lr}: {accuracy:.2f}")

# ------------------------------------------
# Plot accuracy vs learning rate
plt.figure(figsize=(8, 6))
plt.plot(learning_rates, accuracy_results, marker='o', linestyle='--', color='b')
plt.xlabel("Learning Rate")
plt.ylabel("Accuracy Score")
plt.title("Effect of Learning Rate on AdaBoost Classifier Accuracy")
plt.xscale("log")  # Log scale for better visualization
plt.grid(True)
plt.show()

#Q30 Train an XGBoost Classifier for multi-class classification and evaluate using log-loss.
import numpy as np
from xgboost import XGBClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss

# ------------------------------------------
# Generate a synthetic multi-class classification dataset
X, y = make_classification(
    n_samples=1000, 
    n_features=6, 
    n_informative=4, 
    n_redundant=0, 
    n_classes=3,              # Multi-class classification with 3 classes
    random_state=42
)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ------------------------------------------
# Train XGBoost Classifier for multi-class classification
xgb_model = XGBClassifier(
    n_estimators=100,         # Number of boosting rounds
    learning_rate=0.1,        # Learning rate
    max_depth=3,              # Depth of each tree
    objective='multi:softprob',  # Multi-class objective
    num_class=3,              # Number of classes
    random_state=42
)

# Fit the model to training data
xgb_model.fit(X_train, y_train)

# ------------------------------------------
# Predict probabilities for multi-class classification
y_prob = xgb_model.predict_proba(X_test)

# Evaluate model performance using log-loss
logloss = log_loss(y_test, y_prob)
print(f"Log-Loss of XGBoost Classifier: {logloss:.4f}")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Accuracy of AdaBoost Classifier: 0.87
# Mean Absolute Error (MAE) of AdaBoost Regressor: 14.41
# Feature Importance from Gradient Boosting Classifier:
#
#                     Feature  Importance
# 7       mean concave points    0.434897
# 27     worst concave points    0.273841
# 22          worst perimeter    0.050974
# 23               worst area    0.047995
# 21            worst texture    0.047193
# 20             worst radius    0.045435
# 26          worst concavity    0.022999
# 1              mean texture    0.018393
# 16          concavity error    0.015558
# 10             radius error    0.010003
# 13               area error    0.005478
# 24         worst smoothness    0.004507
# 15        compactness error    0.004384
# 17     concave points error    0.003404
# 12          perimeter error    0.002045
# 18           symmetry error    0.001845
# 5          mean compactness    0.001712
# 11            texture error    0.001303
# 28           worst symmetry    0.001284
# 6            mean concavity    0.001199
# 29  worst fractal dimension    0.001087
# 25        worst compactness    0.001012
# 4           mean smoothness    0.000926
# 9    mean fractal dimension    0.000678
# 19  fractal dimension error    0.000596
# 14         smoothness error    0.000380
# 2            mean perimeter    0.000357
# 3                 mean area    0.000308
# 8             mean symmetry    0.000169
# 0               mean radius    0.000037
# R-Squared Score (R²) of Gradient Boosting Regressor: 0.96
# Accuracy of Gradient Boosting Classifier: 0.93
# Accuracy of XGBoost Classifier: 0.94
# XGBoost outperforms Gradient Boosting!
# F1-Score of CatBoost Classifier: 0.93
# Mean Squared Error (MSE) of XGBoost Regressor: 123.24
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\Ashish Maurya\AppData\Roaming\Python\Python312\site-packages\xgboost\training.py:183: UserWarning: [00:03:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Accuracy of XGBoost Classifier: 0.94
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Accuracy with 10 estimators: 0.89
# Accuracy with 50 estimators: 0.87
# Accuracy with 100 estimators: 0.85
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Accuracy with 200 estimators: 0.86
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Accuracy with 300 estimators: 0.86
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# Best Learning Rate: 0.2
# Mean Squared Error (MSE) with best learning rate: 93.92
# F1-Score without class weights: 0.82
#
# Classification Report without Class Weights:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       281
#            1       0.93      0.74      0.82        19
#
#     accuracy                           0.98       300
#    macro avg       0.96      0.87      0.91       300
# weighted avg       0.98      0.98      0.98       300
#
#
# F1-Score with class weights: 0.58
#
# Classification Report with Class Weights:
#                precision    recall  f1-score   support
#
#            0       0.99      0.92      0.95       281
#            1       0.42      0.89      0.58        19
#
#     accuracy                           0.92       300
#    macro avg       0.71      0.91      0.77       300
# weighted avg       0.96      0.92      0.93       300
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Accuracy with learning rate 0.001: 0.88
# Accuracy with learning rate 0.01: 0.88
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Accuracy with learning rate 0.1: 0.89
# Accuracy with learning rate 0.5: 0.90
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Accuracy with learning rate 1.0: 0.87
# Accuracy with learning rate 1.5: 0.86
# Log-Loss of XGBoost Classifier: 0.5463
